# %% [markdown]
# https://developers.kakao.com/docs/latest/ko/local/dev-guide#address-coord

# %%
import pandas as pd
import requests
import json
# Out:
# c:\Users\Lee\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
import pandas as pd
import requests
import json
# url ='https://dapi.kakao.com/v2/local/search/category.${FORMAT}'
# url ='https://dapi.kakao.com/v2/local/search/category.json?category_group_code=PM9&radius=2000'
# 36.993883,127.089649

# searching ='.json?x=36.993883&y=127.089649&radius=2000&category_group_code=PM9'
# url ='https://dapi.kakao.com/v2/local/search/category.${}'.format(searching)

# url ='https://dapi.kakao.com/v2/local/search/category.json?x=36.916583&y=127.132933&radius=2000&category_group_code=PM9'

# url = 'https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=127.0003429871931&y=37.57113559406886'



# headers = {'Authorization': 'KakaoAK {}'.format('masking')}
# data = requests.post(url,headers=headers)
# result = json.loads(data.text)
# result


# documents = result['documents']
# documents
# for data in documents:
  # 127.0003429871931 ,37.57113559406886

### 
# 지번 -> 위도 경도
# searching ='입장면 독정리 290 0'

searching =  '천안시 동남구	구성동 62 7'
url = 'https://dapi.kakao.com/v2/local/search/address.json?query={}'.format(searching)


headers = {'Authorization': 'KakaoAK {}'.format('masking') }
data = requests.post(url,headers=headers)
result = json.loads(data.text)
result
# documents = result['documents']
# documents[0]
# print(documents)
# for data in documents:
#   print(data['address'])  
  # 127.0003429871931 ,37.57113559406886
# Out:
# {'documents': [],
#  'meta': {'is_end': True, 'pageable_count': 0, 'total_count': 0}}

# %%
addressData = pd.read_csv(r'C:\Users\Lee\Desktop\Project\천안시 시각화\천안시_DataDir\202307_도로명주소 한글_전체분\충청남도지번.txt',encoding='cp949',sep='|',header=None)
col_list= ['관리번호','일련번호','법정동코드','시도명','시군구명','법정읍면동명','법정리명','산여부','번지','호','대표여부']
addressData.columns=col_list
addressData = addressData[addressData['시군구명'].isin(['천안시 동남구','천안시 서북구'])]
addressData
# Out:
#                             관리번호  일련번호       법정동코드   시도명     시군구명 법정읍면동명 법정리명  \
# 0      4413025629101030004000001     1  4413325629  충청남도  천안시 서북구    직산읍  모시리
# 1      4413025632102760000000001     1  4413325632  충청남도  천안시 서북구    직산읍  신갈리
# 2      4413034027103000000000001     1  4413134027  충청남도  천안시 동남구    성남면  신사리
# 3      4413034027103000000000001     3  4413134027  충청남도  천안시 동남구    성남면  신사리
# 4      4413034027103000000000001     5  4413134027  충청남도  천안시 동남구    성남면  신사리
# ...                          ...   ...         ...   ...      ...    ...  ...
# 93506  4413331038102740103012993     5  4413331038  충청남도  천안시 서북구    입장면  독정리
# 93507  4413331038102740103012993     6  4413331038  충청남도  천안시 서북구    입장면  독정리
# 93508  4413331038102840000013127     1  4413331038  충청남도  천안시 서북구    입장면  독정리
# 93509  4413331038102870000015693     1  4413331038  충청남도  천안시 서북구    입장면  독정리
# 93510  4413331038102900000013341     1  4413331038  충청남도  천안시 서북구    입장면  독정리
#
#        산여부   번지  호  대표여부
# 0        0  103  4     1
# 1        0  276  0     1
# 2        0  300  0     1
# 3        0  300  3     0
# 4        0  300  5     0
# ...    ...  ... ..   ...
# 93506    0  274  3     0
# 93507    0  274  4     0
# 93508    0  284  0     1
# 93509    0  287  0     1
# 93510    0  290  0     1
#
# [93511 rows x 11 columns]

# %%
# 법정리명      nan값 주의
from tqdm import tqdm

cnt=0

addressCopy = addressData.copy()
# addressCopy = addressCopy[:10]
headers = {'Authorization': 'KakaoAK {}'.format('masking') }
addressCopy['byAPI'] =None
for idx in tqdm(range(len(addressCopy))):
  try:
    address1 = addressCopy.loc[idx,'시군구명']
    address2 = addressCopy.loc[idx,'법정읍면동명']
    address3 = addressCopy.loc[idx,'번지']
    address4 = addressCopy.loc[idx,'호']
    address =  address1 + ' ' + address2 + ' ' + str(address3) + ' ' + str(address4)

    searching = address
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query={}'.format(searching)
    # headers = {'Authorization': 'KakaoAK {}'.format('masking') }
    data = requests.post(url,headers=headers)
    result = json.loads(data.text)
    documents = result['documents']
    

    addressCopy.at[idx,'byAPI'] = documents[0]
  except:
    cnt+=1
    print('쿼리값을 못찾는중:',cnt)
    pass

# %%
# nan값 마저 긁기
address_more = pd.read_pickle(r'C:\Users\Lee\Desktop\천안시_DataDir\addressByAPIpickle.pickle')
address_more
# Out:
#                             관리번호  일련번호       법정동코드   시도명     시군구명 법정읍면동명 법정리명  \
# 0      4413025629101030004000001     1  4413325629  충청남도  천안시 서북구    직산읍  모시리
# 1      4413025632102760000000001     1  4413325632  충청남도  천안시 서북구    직산읍  신갈리
# 2      4413034027103000000000001     1  4413134027  충청남도  천안시 동남구    성남면  신사리
# 3      4413034027103000000000001     3  4413134027  충청남도  천안시 동남구    성남면  신사리
# 4      4413034027103000000000001     5  4413134027  충청남도  천안시 동남구    성남면  신사리
# ...                          ...   ...         ...   ...      ...    ...  ...
# 93506  4413331038102740103012993     5  4413331038  충청남도  천안시 서북구    입장면  독정리
# 93507  4413331038102740103012993     6  4413331038  충청남도  천안시 서북구    입장면  독정리
# 93508  4413331038102840000013127     1  4413331038  충청남도  천안시 서북구    입장면  독정리
# 93509  4413331038102870000015693     1  4413331038  충청남도  천안시 서북구    입장면  독정리
# 93510  4413331038102900000013341     1  4413331038  충청남도  천안시 서북구    입장면  독정리
#
#        산여부   번지  호  대표여부                                              byAPI
# 0        0  103  4     1  {'address': {'address_name': '충남 천안시 서북구 직산읍 모...
# 1        0  276  0     1  {'address': {'address_name': '충남 천안시 서북구 직산읍 군...
# 2        0  300  0     1  {'address': {'address_name': '충남 천안시 동남구 성남면 대...
# 3        0  300  3     0  {'address': {'address_name': '충남 천안시 동남구 성남면 신...
# 4        0  300  5     0  {'address': {'address_name': '충남 천안시 동남구 성남면 신...
# ...    ...  ... ..   ...                                                ...
# 93506    0  274  3     0                                               None
# 93507    0  274  4     0                                               None
# 93508    0  284  0     1                                               None
# 93509    0  287  0     1                                               None
# 93510    0  290  0     1                                               None
#
# [93511 rows x 12 columns]

# %%
address_more_isna = address_more[address_more['byAPI'].isna()]
address_more_isNotna = address_more[~address_more['byAPI'].isna()]
address_more_isNotna.reset_index(inplace=True,drop=True)
address_more_isna.reset_index(inplace=True,drop=True)
print(len(address_more_isNotna)+len(address_more_isna)==len(address_more))
# Out:
# True

# %%
address_more_isna
# Out:
#                             관리번호  일련번호       법정동코드   시도명     시군구명 법정읍면동명 법정리명  \
# 0      4413110100100100005014323     1  4413110100  충청남도  천안시 동남구    대흥동  NaN
# 1      4413110100100630061016432     3  4413110100  충청남도  천안시 동남구    대흥동  NaN
# 2      4413110300100290019015131     1  4413110300  충청남도  천안시 동남구    문화동  NaN
# 3      4413110800100190000016329     2  4413110800  충청남도  천안시 동남구    구성동  NaN
# 4      4413110800100710047024880     3  4413110800  충청남도  천안시 동남구    구성동  NaN
# ...                          ...   ...         ...   ...      ...    ...  ...
# 54454  4413331038102740103012993     5  4413331038  충청남도  천안시 서북구    입장면  독정리
# 54455  4413331038102740103012993     6  4413331038  충청남도  천안시 서북구    입장면  독정리
# 54456  4413331038102840000013127     1  4413331038  충청남도  천안시 서북구    입장면  독정리
# 54457  4413331038102870000015693     1  4413331038  충청남도  천안시 서북구    입장면  독정리
# 54458  4413331038102900000013341     1  4413331038  충청남도  천안시 서북구    입장면  독정리
#
#        산여부   번지   호  대표여부 byAPI
# 0        0   10   5     1  None
# 1        0   63  30     0  None
# 2        0   29  19     1  None
# 3        1   44   1     0  None
# 4        1   44   1     0  None
# ...    ...  ...  ..   ...   ...
# 54454    0  274   3     0  None
# 54455    0  274   4     0  None
# 54456    0  284   0     1  None
# 54457    0  287   0     1  None
# 54458    0  290   0     1  None
#
# [54459 rows x 12 columns]

# %%
# address_more_isna
# 법정리명      nan값 주의
from tqdm import tqdm

cnt=0

addressCopy = address_more_isna.copy()
headers = {'Authorization': 'KakaoAK {}'.format('1d49e941371e685a965fba06520cda68') }
addressCopy['byAPI'] =None
for idx in tqdm(range(len(addressCopy))):
  try:
    address1 = addressCopy.loc[idx,'시군구명']
    address2 = addressCopy.loc[idx,'법정읍면동명']
    address3 = addressCopy.loc[idx,'번지']
    address4 = addressCopy.loc[idx,'호']
    address =  address1 + ' ' + address2 + ' ' + str(address3) + ' ' + str(address4)

    searching = address
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query={}'.format(searching)
    # headers = {'Authorization': 'KakaoAK {}'.format('c454c0e64688ce2bde2dfff9cceced87') }
    data = requests.post(url,headers=headers)
    result = json.loads(data.text)
    documents = result['documents']
    

    addressCopy.at[idx,'byAPI'] = documents[0]
  except:
    cnt+=1
    if cnt%50==0:
      print('쿼리값을 못찾는중:',cnt) 

    pass
# Out:
#   0%|          | 57/54459 [00:02<42:21, 21.41it/s]
# 쿼리값을 못찾는중: 50
#   0%|          | 108/54459 [00:04<44:11, 20.50it/s]
# 쿼리값을 못찾는중: 100
#   2%|▏         | 849/54459 [00:45<44:18, 20.16it/s]
# 쿼리값을 못찾는중: 150
#  27%|██▋       | 14840/54459 [13:58<27:39:20,  2.51s/it]
# 쿼리값을 못찾는중: 200
#  98%|█████████▊| 53368/54459 [49:28<00:56, 19.45it/s]
# 쿼리값을 못찾는중: 250
# 100%|██████████| 54459/54459 [51:06<00:00, 17.76it/s]

# %%
addressCopy
# Out:
#                             관리번호  일련번호       법정동코드   시도명     시군구명 법정읍면동명 법정리명  \
# 0      4413110100100100005014323     1  4413110100  충청남도  천안시 동남구    대흥동  NaN
# 1      4413110100100630061016432     3  4413110100  충청남도  천안시 동남구    대흥동  NaN
# 2      4413110300100290019015131     1  4413110300  충청남도  천안시 동남구    문화동  NaN
# 3      4413110800100190000016329     2  4413110800  충청남도  천안시 동남구    구성동  NaN
# 4      4413110800100710047024880     3  4413110800  충청남도  천안시 동남구    구성동  NaN
# ...                          ...   ...         ...   ...      ...    ...  ...
# 54454  4413331038102740103012993     5  4413331038  충청남도  천안시 서북구    입장면  독정리
# 54455  4413331038102740103012993     6  4413331038  충청남도  천안시 서북구    입장면  독정리
# 54456  4413331038102840000013127     1  4413331038  충청남도  천안시 서북구    입장면  독정리
# 54457  4413331038102870000015693     1  4413331038  충청남도  천안시 서북구    입장면  독정리
# 54458  4413331038102900000013341     1  4413331038  충청남도  천안시 서북구    입장면  독정리
#
#        산여부   번지   호  대표여부                                              byAPI
# 0        0   10   5     1  {'address': {'address_name': '충남 천안시 동남구 대흥동 1...
# 1        0   63  30     0  {'address': {'address_name': '충남 천안시 동남구 대흥동 6...
# 2        0   29  19     1  {'address': {'address_name': '충남 천안시 동남구 문화동 2...
# 3        1   44   1     0                                               None
# 4        1   44   1     0                                               None
# ...    ...  ...  ..   ...                                                ...
# 54454    0  274   3     0  {'address': {'address_name': '충남 천안시 서북구 입장면 도...
# 54455    0  274   4     0  {'address': {'address_name': '충남 천안시 서북구 입장면 도...
# 54456    0  284   0     1  {'address': {'address_name': '충남 천안시 서북구 입장면 도...
# 54457    0  287   0     1  {'address': {'address_name': '충남 천안시 서북구 입장면 독...
# 54458    0  290   0     1  {'address': {'address_name': '충남 천안시 서북구 입장면 가...
#
# [54459 rows x 12 columns]

# %%
merged_df = pd.concat([address_more_isNotna,addressCopy],ignore_index=True)
print(len(merged_df)==len(address_more))
# Out:
# True

# %%
merged_df = merged_df.dropna(subset=['byAPI'])
merged_df.isna().sum()
# Out:
# 관리번호          0
# 일련번호          0
# 법정동코드         0
# 시도명           0
# 시군구명          0
# 법정읍면동명        0
# 법정리명      34402
# 산여부           0
# 번지            0
# 호             0
# 대표여부          0
# byAPI         0
# dtype: int64

# %% [markdown]
# # 좌표 -> category

# %%
x = addressCopy['byAPI'][0]['address']['x']
y = addressCopy['byAPI'][0]['address']['y']

searching ='category_group_code={code}&x={x}&y={y}&radius={radius}'.format(code='CS2',x=str(x),y=str(y),radius=2000)
# searching ='{code}&{radius}'.format(code='PM9',radius=2)

url='https://dapi.kakao.com/v2/local/search/category.json?{}'.format(searching)

# url='https://dapi.kakao.com/v2/local/search/category.json?category_group_code=PM9&radius=2000'


headers = {'Authorization': 'KakaoAK {}'.format('c454c0e64688ce2bde2dfff9cceced87') }

data=requests.post(url,headers=headers)
result = json.loads(data.text)
result
# documents = result['documents']
# documents
# Out:
# {'documents': [{'address_name': '충남 천안시 서북구 직산읍 부송리 40-1',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > 미니스톱',
#    'distance': '459',
#    'id': '1798386187',
#    'phone': '1577-9621',
#    'place_name': '미니스톱 천안부송산단점',
#    'place_url': 'http://place.map.kakao.com/1798386187',
#    'road_address_name': '충남 천안시 서북구 직산읍 부송1길 7',
#    'x': '127.1382046146598',
#    'y': '36.874597978857075'},
#   {'address_name': '충남 천안시 서북구 직산읍 부송리 136',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > CU',
#    'distance': '706',
#    'id': '36638305',
#    'phone': '1577-8007',
#    'place_name': 'CU 천안직산공단점',
#    'place_url': 'http://place.map.kakao.com/36638305',
#    'road_address_name': '충남 천안시 서북구 직산읍 부송4길 5',
#    'x': '127.131707131928',
#    'y': '36.875900238685'},
#   {'address_name': '충남 천안시 서북구 직산읍 모시리 322',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > GS25',
#    'distance': '947',
#    'id': '1441439474',
#    'phone': '',
#    'place_name': 'GS25 직산우성점',
#    'place_url': 'http://place.map.kakao.com/1441439474',
#    'road_address_name': '충남 천안시 서북구 직산읍 자은가리1길 66',
#    'x': '127.12579051154191',
#    'y': '36.8697214901665'},
#   {'address_name': '충남 천안시 서북구 성거읍 신월리 398-13',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > CU',
#    'distance': '1061',
#    'id': '1860800013',
#    'phone': '041-583-3185',
#    'place_name': 'CU 천안직산대로점',
#    'place_url': 'http://place.map.kakao.com/1860800013',
#    'road_address_name': '충남 천안시 서북구 성거읍 천안대로 1482',
#    'x': '127.147954750867',
#    'y': '36.8728525229051'},
#   {'address_name': '충남 천안시 서북구 성거읍 신월리 399-22',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > GS25',
#    'distance': '1068',
#    'id': '1812880908',
#    'phone': '',
#    'place_name': 'GS25 직산대로점',
#    'place_url': 'http://place.map.kakao.com/1812880908',
#    'road_address_name': '충남 천안시 서북구 성거읍 천안대로 1462',
#    'x': '127.14831257569655',
#    'y': '36.87113277618414'},
#   {'address_name': '충남 천안시 서북구 업성동 160-4',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > 이마트24',
#    'distance': '1189',
#    'id': '1090810116',
#    'phone': '02-6916-1500',
#    'place_name': '이마트24 천안업성점',
#    'place_url': 'http://place.map.kakao.com/1090810116',
#    'road_address_name': '충남 천안시 서북구 업성3길 51',
#    'x': '127.13631458769417',
#    'y': '36.86001222374268'},
#   {'address_name': '충남 천안시 서북구 직산읍 모시리 253-42',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > 세븐일레븐',
#    'distance': '1186',
#    'id': '19429890',
#    'phone': '',
#    'place_name': '세븐일레븐 천안4공단쉼터점',
#    'place_url': 'http://place.map.kakao.com/19429890',
#    'road_address_name': '충남 천안시 서북구 직산읍 4산단7로 90',
#    'x': '127.12347290083407',
#    'y': '36.86800732161813'},
#   {'address_name': '충남 천안시 서북구 직산읍 자은가리 148-2',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > CU',
#    'distance': '993',
#    'id': '798637328',
#    'phone': '041-583-2066',
#    'place_name': 'CU 천안직산우성점',
#    'place_url': 'http://place.map.kakao.com/798637328',
#    'road_address_name': '충남 천안시 서북구 직산읍 자은가리1길 57',
#    'x': '127.125253612582',
#    'y': '36.8699157940302'},
#   {'address_name': '충남 천안시 서북구 직산읍 모시리 237-15',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > CU',
#    'distance': '1332',
#    'id': '1922815970',
#    'phone': '041-581-9074',
#    'place_name': 'CU 천안4공단점',
#    'place_url': 'http://place.map.kakao.com/1922815970',
#    'road_address_name': '충남 천안시 서북구 직산읍 4산단7로 34',
#    'x': '127.12442223148383',
#    'y': '36.863493611736075'},
#   {'address_name': '충남 천안시 서북구 직산읍 삼은리 76-76',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > 이마트24',
#    'distance': '1373',
#    'id': '774291570',
#    'phone': '02-6916-1500',
#    'place_name': '이마트24 천안직산빌리지점',
#    'place_url': 'http://place.map.kakao.com/774291570',
#    'road_address_name': '충남 천안시 서북구 직산읍 삼은2길 16',
#    'x': '127.14863692209715',
#    'y': '36.878190692016'},
#   {'address_name': '충남 천안시 서북구 직산읍 삼은리 76-139',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > GS25',
#    'distance': '1408',
#    'id': '12295749',
#    'phone': '041-583-2985',
#    'place_name': 'GS25 직산중앙점',
#    'place_url': 'http://place.map.kakao.com/12295749',
#    'road_address_name': '충남 천안시 서북구 직산읍 아랫말2길 1',
#    'x': '127.149919337291',
#    'y': '36.8772258051517'},
#   {'address_name': '충남 천안시 서북구 직산읍 삼은리 76-430',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > CU',
#    'distance': '1490',
#    'id': '1383668997',
#    'phone': '',
#    'place_name': 'CU 천안직산타운점',
#    'place_url': 'http://place.map.kakao.com/1383668997',
#    'road_address_name': '충남 천안시 서북구 직산읍 삼은4길 19',
#    'x': '127.14925593803456',
#    'y': '36.87927123617591'},
#   {'address_name': '충남 천안시 서북구 업성동 174-3',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > GS25',
#    'distance': '1575',
#    'id': '1659688626',
#    'phone': '',
#    'place_name': 'GS25 천안번영로점',
#    'place_url': 'http://place.map.kakao.com/1659688626',
#    'road_address_name': '충남 천안시 서북구 번영로 704',
#    'x': '127.13741746278889',
#    'y': '36.8565579263316'},
#   {'address_name': '충남 천안시 서북구 직산읍 모시리 253-18',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > GS25',
#    'distance': '1643',
#    'id': '25655462',
#    'phone': '041-588-0561',
#    'place_name': 'GS25 천안4공단점',
#    'place_url': 'http://place.map.kakao.com/25655462',
#    'road_address_name': '충남 천안시 서북구 직산읍 상덕로 12',
#    'x': '127.118118500109',
#    'y': '36.8685390069206'},
#   {'address_name': '충남 천안시 서북구 직산읍 양당리 344-14',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > CU',
#    'distance': '1580',
#    'id': '1927853141',
#    'phone': '',
#    'place_name': 'CU 직산상덕로드점',
#    'place_url': 'http://place.map.kakao.com/1927853141',
#    'road_address_name': '충남 천안시 서북구 직산읍 상덕로 39',
#    'x': '127.11861569588984',
#    'y': '36.8709498598098'}],
#  'meta': {'is_end': False,
#   'pageable_count': 30,
#   'same_name': None,
#   'total_count': 30}}

# %%
df = pd.read_csv(r'C:\Users\Lee\Desktop\Project\천안시 시각화\천안시_DataDir\202307_도로명주소 한글_전체분\202307_도로명주소 한글_전체분.txt',encoding='cp949',sep='|',header=None)
df
# Out:
#                                 0           1     2        3    4    5   6   \
# 0       44131120100012500001700003  4413112000  충청남도  천안시 동남구  구룡동  NaN   0
# 1       44131120100012500001700003  4413112000  충청남도  천안시 동남구  구룡동  NaN   0
# 2       44131120100012500001700003  4413112000  충청남도  천안시 동남구  구룡동  NaN   0
# 3       44131120100012500001800000  4413112000  충청남도  천안시 동남구  구룡동  NaN   0
# 4       44131120100012500001800000  4413112000  충청남도  천안시 동남구  구룡동  NaN   0
# ...                            ...         ...   ...      ...  ...  ...  ..
# 185919  44825250486137800001900004  4482525021  충청남도      태안군  태안읍  동문리   0
# 185920  44825250486137800001900005  4482525021  충청남도      태안군  태안읍  동문리   0
# 185921  44825250486137800001900005  4482525021  충청남도      태안군  태안읍  동문리   1
# 185922  44825250486137800001900005  4482525021  충청남도      태안군  태안읍  동문리   0
# 185923  44825250486137800002200000  4482525021  충청남도      태안군  태안읍  동문리   0
#
#          7   8             9   10  11  12  13
# 0       418  11  441311000125   0  17   3 NaN
# 1       418  14  441311000125   0  17   3 NaN
# 2       418  13  441311000125   0  17   3 NaN
# 3       652   6  441311000125   0  18   0 NaN
# 4       651   3  441311000125   0  18   0 NaN
# ...     ...  ..           ...  ..  ..  ..  ..
# 185919  746   2  448254861378   0  19   4 NaN
# 185920  841   0  448254861378   0  19   5 NaN
# 185921   16   6  448254861378   0  19   5 NaN
# 185922  875   0  448254861378   0  19   5 NaN
# 185923  841   0  448254861378   0  22   0 NaN
#
# [185924 rows x 14 columns]

# %%
col_list= ['관리번호','일련번호','법정동코드','시도명','시군구명','법정읍면동명','법정리명','산여부','번지','호','대표여부']
df.columns=col_list
df
# Out:
#                              관리번호  일련번호       법정동코드   시도명     시군구명 법정읍면동명  \
# 0       4413025629101030004000001     1  4413325629  충청남도  천안시 서북구    직산읍
# 1       4413025632102760000000001     1  4413325632  충청남도  천안시 서북구    직산읍
# 2       4413034027103000000000001     1  4413134027  충청남도  천안시 동남구    성남면
# 3       4413034027103000000000001     3  4413134027  충청남도  천안시 동남구    성남면
# 4       4413034027103000000000001     5  4413134027  충청남도  천안시 동남구    성남면
# ...                           ...   ...         ...   ...      ...    ...
# 675683  4483040033105360000077007     1  4427039033  충청남도      당진시    송산면
# 675684  4483040033105360000077007     2  4427039033  충청남도      당진시    송산면
# 675685  4483040033200110001075209     1  4427039033  충청남도      당진시    송산면
# 675686  4483040033200110001075209     2  4427039033  충청남도      당진시    송산면
# 675687  4483040033200110001075209     3  4427039033  충청남도      당진시    송산면
#
#        법정리명  산여부   번지   호  대표여부
# 0       모시리    0  103   4     1
# 1       신갈리    0  276   0     1
# 2       신사리    0  300   0     1
# 3       신사리    0  300   3     0
# 4       신사리    0  300   5     0
# ...     ...  ...  ...  ..   ...
# 675683  가곡리    0  536   0     1
# 675684  가곡리    0  537   0     0
# 675685  가곡리    0  373  37     1
# 675686  가곡리    0  373  39     0
# 675687  가곡리    0  373  35     0
#
# [675688 rows x 11 columns]

# %%
df['시군구명'].value_counts()
addressDB = df[df['시군구명'].isin(['천안시 동남구','천안시 서북구'])]
# 입장면 독정리 290 0

# %%
# df[df['관리번호']=='4413025632102760000000001']
df.isna().sum()
# Out:
# 관리번호           0
# 일련번호           0
# 법정동코드          0
# 시도명            0
# 시군구명           0
# 법정읍면동명         0
# 법정리명      104196
# 산여부            0
# 번지             0
# 호              0
# 대표여부           0
# dtype: int64

# %%
부가정보 = pd.read_csv(r'C:\Users\Lee\Desktop\Project\천안시 시각화\천안시_DataDir\202307_도로명주소 한글_전체분\충청남도부가정보.txt',encoding='cp949',sep='|',header=None)
부가정보
# Out:
#                                 0             1    2      3   4   5    6  \
# 0       4413025629101030004000001  4.413326e+09  직산읍  31039 NaN NaN  NaN
# 1       4413025632102760000000001  4.413326e+09  직산읍  31040 NaN NaN  NaN
# 2       4413034027103000000000001  4.413134e+09  성남면  31245 NaN NaN  NaN
# 3       4413110100100010001010693  4.413151e+09  중앙동  31128 NaN NaN  NaN
# 4       4413110100100010003014920  4.413151e+09  중앙동  31128 NaN NaN  NaN
# ...                           ...           ...  ...    ...  ..  ..  ...
# 489753  4483040033103940031075072  4.427039e+09  송산면  31709 NaN NaN  NaN
# 489754  4483040033104990001075556  4.427039e+09  송산면  31709 NaN NaN  NaN
# 489755  4483040033105320000077072  4.427039e+09  송산면  31709 NaN NaN  NaN
# 489756  4483040033105360000077007  4.427039e+09  송산면  31709 NaN NaN  NaN
# 489757  4483040033200110001075209  4.427039e+09  송산면  31709 NaN NaN  NaN
#
#                 7  8
# 0             NaN  0
# 1        (주)대성이앤지  0
# 2             NaN  0
# 3             NaN  0
# 4           두나무빌딩  0
# ...           ... ..
# 489753        NaN  0
# 489754  당진시자원순환센터  0
# 489755        관리실  0
# 489756        NaN  0
# 489757        NaN  0
#
# [489758 rows x 9 columns]

# %%
부가정보.loc[:,7].isna().sum()
# Out:
# 449543
